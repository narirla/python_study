# %% [markdown]
# 1.	화면에 아래 문장을 출력하시요.
# 신씨가 소리질렀다. "도둑이야".

# %%
print('신씨가 소리질렀다. "도둑이야".')
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %%
s ='신씨가 소리질렀다. "도둑이야".'
print( s )
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %% [markdown]
# 2.다음 표는 삼성전자의 일부 투자정보이다. 변수를 사용해서 시가총액, 현재가, PER 변수를 선언하시요.
# 항목	값
# 시가총액	298조
# 현재가	50,000원
# PER	15.79

# %%
#2번 문제 정답
시가총액 = 2980000000000
현재가 = 50000
PER = 15.79

# %% [markdown]
# 3.	자동차 번호가 다음과 같을 때 뒤에 4자리만 출력하세요.
# license_plate = "24가 2210"

# %%
license_plate = "24가 2210"
license_plate[-4::]
# Out:
# '2210'

# %% [markdown]
# 4.	아래의 문자열에서 '홀' 만 출력하세요.
# string = "홀짝홀짝홀짝"

# %%
string = "홀짝홀짝홀짝"
print(string[::2])
# Out:
# 홀홀홀

# %% [markdown]
# 5.	아래의 전화번호에서 하이푼 ('-')을 제거하고 출력하세요.
# phone_number = "010-1111-2222"
# 실행 예
# 010 1111 2222

# %%
phone_number = "010-1111-2222"
print(phone_number.replace('-', ' '))
print( phone_number.split('-'))
# Out:
# 010 1111 2222
# ['010', '1111', '2222']

# %%
import re
phone_number = "010-1111#2222@3333"
re.sub('[-#@]', ' ', phone_number)
# Out:
# '010 1111 2222 3333'

# %% [markdown]
# 6.	url 에 저장된 웹 페이지 주소에서 도메인을 출력하세요.
# url = "http://sharebook.kr"
# 실행 예:
# kr

# %%
#6번 문제 정답
url = "http://sharebook.kr"
print(url.split('.') )
print(url.split('.')[-1] )
# Out:
# ['http://sharebook', 'kr']
# kr

# %%
url = "http://sharebook.kr"
url[-2::]
# Out:
# 'kr'

# %% [markdown]
# 7.	다음과 같은 문자열이 있을 때 이를 대문자 BTC_KRW로 변경하세요.
# ticker = "btc_krw"

# %%
ticker = "btc_krw"
print(ticker.upper())
# Out:
# BTC_KRW

# %% [markdown]
# 8.	movie_rank 리스트에는 아래와 같이 네 개의 영화 제목이 바인딩되어 있다. "슈퍼맨"을 "닥터 스트레인지"와 "스플릿" 사이에 추가하라.
# movie_rank = ['닥터 스트레인지', '스플릿', '럭키', '배트맨']

# %%
movie_rank = ['닥터 스트레인지', '스플릿', '럭키', '배트맨']
movie_rank.insert(1, '슈퍼맨')

print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈퍼맨', '스플릿', '럭키', '배트맨']

# %% [markdown]
# 9.	price 변수에는 날짜와 종가 정보가 저장돼 있다. 날짜 정보를 제외하고 가격 정보만을 출력하라. (힌트 : 슬라이싱)
# price = ['20180728', 100, 130, 140, 150, 160, 170]
# 출력 예시:
# [100, 130, 140, 150, 160, 170]

# %%
price = ['20180728', 100, 130, 140, 150, 160, 170]
price[1:]
# Out:
# [100, 130, 140, 150, 160, 170]

# %% [markdown]
# 10.	interest 리스트는 아래와 같다.
# interest = ['삼성전자', 'LG전자', 'Naver', 'SK하이닉스', '미래에셋대우']
# interest 리스트를 사용하여 아래와 같이 화면에 출력하라.
# 출력 예시:
# 삼성전자 LG전자 Naver SK하이닉스 미래에셋대우

# %%
interest = ['삼성전자', 'LG 전자', 'Naver', 'SK 하이닉스', '미래에셋대우']
a, b, c, d, e = interest

print(a, b, c, d, e)
# Out:
# 삼성전자 LG 전자 Naver SK 하이닉스 미래에셋대우

# %%
my1 = ['aa','bb','cc']
print( ' '.join( my1) )
print( '-'.join( my1) )
# Out:
# aa bb cc
# aa-bb-cc

# %%
interest = ['삼성전자', 'LG 전자', 'Naver', 'SK 하이닉스', '미래에셋대우']
print(" ".join(interest))
# Out:
# 삼성전자 LG 전자 Naver SK 하이닉스 미래에셋대우
