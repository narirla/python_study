# %%
a=-10
if a>0:
    print('0보다 크다')

print('hello')
# Out:
# hello

# %%
a= -10
if a>0:
    print('0보다 크다')
else:
    print( '아니다')

print('hello')
# Out:
# 아니다
# hello

# %% [markdown]
# 입력한 점수가 70점이상이면 '합격' 아니면 '불합격' 출력하시요

# %%
jumsu = input('점수:')
jumsu = int(jumsu)
if jumsu>=70:
    print('합격')
else:
    print('불합격')
# Out:
# 불합격

# %%
jumsu = input('점수:')
jumsu = int(jumsu)
rst = '합격' if jumsu>=70 else '불합격'
print( rst )
