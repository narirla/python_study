# %% [markdown]
# True인경우 if 관계또는논리 else False인경우

# %%
a = -5
rst = 100 if a>0 else 200
print( rst )
# Out:
# 200

# %% [markdown]
# ### 퀴즈
# - 점수가 70점이상이면 '합격' 아니면 '불합격' 인 경우
# - 점수가 92 점인 경우 합격여부를 구하시요
