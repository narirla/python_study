# %%
print('hello') #표준출력(모니터)
# Out:
# hello

# %% [markdown]
# # 표준입력(키보드)

# %%
a = input('입력:')
print( a )
print(type(a) )
# Out:
# 3.14
# <class 'str'>

# %%
# 3.14*'5'**2 X

# %% [markdown]
# ## 입력한 반지름의 원의 면적을 구하시요

# %%
r = input('반지름입력:')
r = int(r)
circle_area = 3.14*r**2
print( circle_area)
# Out:
# 314.0
